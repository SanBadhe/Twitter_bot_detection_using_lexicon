# %%
import csv
import tweepy
import time


consumer_key = '########'
consumer_secret = '#######'
access_token = '########'
access_token_secret = '########'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

def getData(usernames):
    test = api.lookup_users(usernames)
    for username in test:
        try:
            #print (user)
            data = dataFormat(username)
            #print (data)
            with open('Userbased_Output1.csv','a', newline='', encoding='utf8') as c:
                wr = csv.writer(c, quoting=csv.QUOTE_ALL)
                wr.writerow(data)

            c.close()
        except Exception as e:
            print (e)


def dataFormat(user):
    status = user.status if hasattr(user, 'status') else ''
    name = ''.join(user.name).encode('utf-8').strip() if hasattr(user, 'name') else ''
    location = ''.join(user.location).encode('utf-8').strip() if hasattr(user, 'location') else ''
    description = ''.join(user.description).encode('utf-8').strip() if hasattr(user, 'description') else ''
    #url = ''.join(user.url).encode('utf-8').strip() if hasattr(user, 'url') else ''
    data = [user.id,user.id_str,user.screen_name,location,description,user.url,user.followers_count,user.friends_count,user.listed_count,user.created_at,user.favourites_count,user.verified,user.statuses_count,user.lang,status,user.default_profile,user.default_profile_image,user.has_extended_profile,name, 0]
    return data


userList = []

counter = 0

#need to add one extra line with space in the userinput file
with open('Botlist.txt','rU') as f:
    for line in f:
        counter+=1
        userList += line.strip(),
        if counter == 99 or line == " ":
            counter=0
            getData(userList)
            userList = []     

#print (userList)
# Out:
# c:\users\sanket\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:50: DeprecationWarning: 'U' mode is deprecated

# %%
Excel has limit of 32,000 charecter in each cell hence we used multiple cells over here

# %%
import csv
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream
import pprint
import time



consumer_key = 'bjFdraCy5qgh2ZN4lwZly0Ekb'
consumer_secret = 'ORmDIHSv0676tqhzjMGmXPLlyC4DPwmp6k6wDNZPXFraj59p3e'
access_token = '593357593-P1Zxz6ZVSnuDBHcHOFy6CM8TnlOCLFLR6Jjskw25'
access_token_secret = 'tNgsfAK2QjIsXjzloq83LyMqzISHCG6puuVFvXIdtaapU'

oauth = OAuth(access_token, access_token_secret,consumer_key, consumer_secret)
twitter = Twitter(auth=oauth)



def getData(usernames,counter):
    for username in usernames:
        if username.startswith('"') and username.endswith('"'): username = username[1:-1]
        try:
            #initialize a list to hold all the tweepy Tweets
            alltweets = []
            new_tweets = twitter.statuses.user_timeline(user_id=username, count = 200)
            alltweets.extend(new_tweets)            
            #save the id of the oldest tweet less one
            oldest = alltweets[-1]['id'] - 1
            #print (tweets)
            #keep grabbing tweets until there are no tweets left to grab
            while len(new_tweets) > 0:
                counter+=1
                #all subsiquent requests use the max_id param to prevent duplicates
                new_tweets = twitter.statuses.user_timeline(user_id=username,count=200,max_id=oldest)
                #save most recent tweets
                alltweets.extend(new_tweets)
                # security
                #time.sleep(2)
                #update the id of the oldest tweet less one
                oldest = alltweets[-1]['id'] - 1
            data = dataFormat(alltweets,username)
            with open('tweets_honeypot.csv','a', newline='', encoding='utf8') as c:
                wr = csv.writer(c, quoting=csv.QUOTE_ALL)
                wr.writerow(data)

            c.close()
        except Exception as e:
            print (username,e)

    print ('done')


def dataFormat(tweets,username):
    created_at1 =[]
    created_at2 =[]
    created_at3 =[]
    created_at4 =[]
    created_at5 =[]
    created_at6 =[]
    created_at7 =[]
    created_at8 =[]
    texts1 = []
    texts2 = []
    texts3 = []
    texts4 = []
    texts5 = []
    texts6 = []
    texts7 = []
    texts8 = []
    texts9 = []
    texts10 = []
    texts11 = []
    texts12 = []
    texts13 = []
    texts14 = []
    texts15 = []
    texts16 = []
    texts17 = []
    texts18 = []
    texts19 = []
    tweet_downloaded = 0
    in_reply = 0
    total_usrmention = 0
    fav_count = 0
    retweet_count = 0
    for tweet in tweets:
        if tweet['lang']=="en":
            if 'created_at' in tweet and (sum(len(str(i)) for i in created_at1) <=30000):
                created_at1.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at2) <=30000):
                created_at2.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at3) <=30000):
                created_at3.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at4) <=30000):
                created_at4.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at5) <=30000):
                created_at5.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at6) <=30000):
                created_at6.append(''.join(tweet['created_at']).encode('utf-8').strip())
            elif 'created_at' in tweet and (sum(len(str(i)) for i in created_at7) <=30000):
                created_at7.append(''.join(tweet['created_at']).encode('utf-8').strip())
            else :
                created_at8.append(''.join(tweet['created_at']).encode('utf-8').strip())
            if (('in_reply_to_screen_name' in tweet) and (tweet['in_reply_to_screen_name'] is not None)):
                in_reply += 1
            if 'text' in tweet and (sum(len(str(i)) for i in texts1) <=30000):
                texts1.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts2) <=30000):
                texts2.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts3) <=30000):
                texts3.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts4) <=30000):
                texts4.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts5) <=30000):
                texts5.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts6) <=30000):
                texts6.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts7) <=30000):
                texts7.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts8) <=30000):
                texts8.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts9) <=30000):
                texts9.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts10) <=30000):
                texts10.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts11) <=30000):
                texts11.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts12) <=30000):
                texts12.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts13) <=30000):
                texts13.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts14) <=30000):
                texts14.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts15) <=30000):
                texts15.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts16) <=30000):
                texts16.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts17) <=30000):
                texts17.append(''.join(tweet['text']).encode('utf-8').strip())
            elif 'text' in tweet and (sum(len(str(i)) for i in texts18) <=30000):
                texts18.append(''.join(tweet['text']).encode('utf-8').strip())
            else :
                texts19.append(''.join(tweet['text']).encode('utf-8').strip())
            if 'entities' in tweet and tweet['entities']['user_mentions']:
                total_usrmention +=len(tweet['entities']['user_mentions'])
            if 'favorite_count' in tweet and tweet['favorite_count'] > 0:
                fav_count +=1
            if 'retweet_count' in tweet and tweet['retweet_count'] > 0:
                retweet_count +=1
            if 'text' in tweet:
                tweet_downloaded +=1
    data = [username,in_reply,retweet_count,fav_count,total_usrmention,tweet_downloaded,created_at1,created_at2,created_at3,created_at4,created_at5,created_at6,created_at7,created_at8,texts1,texts2,texts3,texts4,texts5,texts6,texts7,texts8,texts9,texts10,texts11,texts12,texts13,texts14,texts15,texts16,texts17,texts18,texts19]
    return data

userList = []

with open('Botlist.txt','rU') as f:
    for line in f:
        userList += line.strip(),

counter = 0
getData(userList,counter)
# Out:
# done

# %%
import glob
import string
import ast
import json
import time

from datetime import date
from dateutil import parser
import datetime as dt

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
from scipy import interp
from scipy import stats
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from collections import OrderedDict, defaultdict, Counter
from nltk.tokenize import TweetTokenizer

# Imports

import glob
import string
import ast

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.tree import DecisionTreeClassifier, export_graphviz 
from sklearn.ensemble import ExtraTreesClassifier

#metrics
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix, f1_score, roc_curve, auc
from sklearn.metrics import precision_recall_fscore_support, classification_report
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import roc_curve, auc
# Out:
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
File size was huge for tweets hence data is downloaded in chunks and in the following code we are appending the data

# %% [markdown]
# df1 = pd.read_csv('output_1.csv', index_col='id', sep=',')
# df2 = pd.read_csv('output_2.csv', index_col='id', sep=',')
# df3 = pd.read_csv('output_3.csv', index_col='id', sep=',')
# dfList=[]
# dfList.append(df1)
# dfList.append(df2)
# dfList.append(df3)
# ConcatDf=pd.concat(dfList, axis=0)

# %%
df4 = pd.read_csv('tweets_honeypot2.csv', index_col='id', sep=',')
df5 = pd.read_csv('tweets_honeypot1.csv', index_col='id', sep=',')
dfList=[]
dfList.append(df4)
dfList.append(df5)
ConcatDf1=pd.concat(dfList, axis=0)

# %%
dfList=[]
dfList.append(ConcatDf1)
dfList.append(ConcatDf)
tweets=pd.concat(dfList, axis=0)

# %%
tweets
# Out:
#               id_str  In_reply  retweet_count  fav_count  total_usrmention  \
# id
# 614              614       547           1280        629              2294
# 1038            1038        76            311         90               403
# 1437            1437      1194            209        239              1903
# 2615            2615       240            181        124               579
# 3148            3148       165            330        555               822
# 5593            5593       191            396        218               712
# 9375            9375       167            125        179               415
# 10336          10336       501           2256        731              3963
# 10698          10698        68             45         55               134
# 11718          11718       940           1598        861              3991
# 12527          12527      2161            146         80              2535
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21895 entries, 614 to 628493945
# Data columns (total 27 columns):
# id_str                21895 non-null int64
# In_reply              21895 non-null int64
# retweet_count         21895 non-null int64
# fav_count             21895 non-null int64
# total_usrmention      21895 non-null int64
# Tweet_Downloaded      21895 non-null int64
# created_at_tweets1    21895 non-null object
# created_at_tweets2    21895 non-null object
# created_at_tweets3    21895 non-null object
# created_at_tweets4    21895 non-null object
# texts1                21895 non-null object
# texts2                21895 non-null object
# texts3                21895 non-null object
# texts4                21895 non-null object
# texts5                21895 non-null object
# texts6                21895 non-null object
# texts7                21895 non-null object
# texts8                21895 non-null object
# texts9                21895 non-null object
# ...

# %%
Data frame for user base information a

# %%
df6 = pd.read_csv('Userbased_Output.csv', index_col='id', sep=',')
df7 = pd.read_csv('Userbased_Output1.csv', index_col='id', sep=',')
dfList=[]
dfList.append(df6)
dfList.append(df7)
UserBased=pd.concat(dfList, axis=0)

# %%
#UserBased data
UserBased
# Out:
#             id_str      screen_name  \
# id
# 6301          6301       msjacbowie
# 10836        10836        rex_huang
# 10997        10997     philcampbell
# 633293      633293      iboughtamac
# 717883      717883           djdick
# 763068      763068           vuchuu
# 783705      783705         davepeck
# 788352      788352   miguelcarrasco
# 810011      810011    ChicagoWebDev
# 815299      815299       benphoster
# 817045      817045     bizopinsider
# 964981      964981    danieledlauer
# 1091571    1091571    materialBITCH
# 1303381    1303381      scottparent
# 1322691    1322691        neilpatel
# 1467621    1467621        MissTrade
# 1599001    1599001          ohgizmo
# 1907361    1907361           salnsg
# 2077351    2077351     simonlazenby
# 2157321    2157321        c_johnson
# 2219081    2219081         LasVegas
# 2243161    2243161         skarritt
# 2269491    2269491          soJelle
# 2695911    2695911         stoneage
# 2884771    2884771         Newsweek
# ...

# %%
UserBased.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24212 entries, 6301 to 73002678
# Data columns (total 19 columns):
# id_str                   24212 non-null int64
# screen_name              24212 non-null object
# location                 24212 non-null object
# description              24212 non-null object
# url                      14828 non-null object
# followers_count          24212 non-null int64
# friends_count            24212 non-null int64
# listedcount              24212 non-null int64
# created_at               24212 non-null object
# favourites_count         24212 non-null int64
# verified                 24212 non-null bool
# statuses_count           24212 non-null int64
# lang                     24212 non-null object
# status                   21867 non-null object
# default_profile          24212 non-null bool
# default_profile_image    24212 non-null bool
# has_extended_profile     24212 non-null bool
# name                     24212 non-null object
# ...

# %%
Merged userbased information with tweet based on user id

# %%
df_all_data = pd.merge(UserBased, tweets, left_index=True, right_index=True)

# %%
In the following section we are counting sentiments correponding to each user id

# %%
import csv

wordList = defaultdict(list)
emotionList = defaultdict(list)
with open('NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt', 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    headerRows = [i for i in range(0, 2)]
    for row in headerRows:
        next(reader)
    for word, emotion, present in reader:
        if int(present) == 1:
            wordList[word].append(emotion)
            emotionList[emotion].append(word)

# %%
tt = TweetTokenizer()

# %%
def generate_emotion_count(string, tokenizer):
    emoCount = Counter()
    for token in tt.tokenize(string):
        token = token.lower()
        emoCount += Counter(wordList[token])
    return emoCount

# %%
emotionCounts1  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts1']]
print('Done1')
emotionCounts2  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts2']]
print('Done2')
emotionCounts3  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts3']]
print('Done3')
emotionCounts4  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts4']]
print('Done4')
emotionCounts5  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts5']]
print('Done5')
emotionCounts6  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts6']]
print('Done6')
emotionCounts7  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts7']]
print('Done7')
emotionCounts8  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts8']]
print('Done8')
emotionCounts9  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts9']]
print('Done9')
emotionCounts10  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts10']]
print('Done10')
emotionCounts11  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts11']]
print('Done11')
emotionCounts12  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts12']]
print('Done12')
emotionCounts13  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts13']]
print('Done13')
emotionCounts14  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts14']]
print('Done14')
emotionCounts15  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts15']]
print('Done15')
emotionCounts16  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts16']]
print('Done16')
emotionCounts17  = [generate_emotion_count(tweet, tt) for tweet in df_all_data['texts17']]
print('Done17')
# Out:
# Done1
# Done2
# Done3
# Done4
# Done5
# Done6
# Done7
# Done8
# Done9
# Done10
# Done11
# Done12
# Done13
# Done14
# Done15
# Done16
# Done17

# %%
emotion_df1  = pd.DataFrame(emotionCounts1, index=df_all_data['texts1'].index)
emotion_df1 = emotion_df1.fillna(0)
emotion_df2  = pd.DataFrame(emotionCounts2, index=df_all_data['texts2'].index)
emotion_df2 = emotion_df2.fillna(0)
emotion_df = emotion_df1.add(emotion_df2, fill_value=0)
emotion_df3  = pd.DataFrame(emotionCounts3, index=df_all_data['texts3'].index)
emotion_df3 = emotion_df3.fillna(0)
emotion_df = emotion_df.add(emotion_df3, fill_value=0)
emotion_df4  = pd.DataFrame(emotionCounts4, index=df_all_data['texts4'].index)
emotion_df4 = emotion_df4.fillna(0)
emotion_df = emotion_df.add(emotion_df4, fill_value=0)
emotion_df5  = pd.DataFrame(emotionCounts5, index=df_all_data['texts5'].index)
emotion_df5 = emotion_df5.fillna(0)
emotion_df = emotion_df.add(emotion_df5, fill_value=0)
emotion_df6  = pd.DataFrame(emotionCounts6, index=df_all_data['texts6'].index)
emotion_df6 = emotion_df6.fillna(0)
emotion_df = emotion_df.add(emotion_df6, fill_value=0)
emotion_df7  = pd.DataFrame(emotionCounts7, index=df_all_data['texts7'].index)
emotion_df7 = emotion_df7.fillna(0)
emotion_df = emotion_df.add(emotion_df7, fill_value=0)
emotion_df8  = pd.DataFrame(emotionCounts8, index=df_all_data['texts8'].index)
emotion_df8 = emotion_df8.fillna(0)
emotion_df = emotion_df.add(emotion_df8, fill_value=0)
emotion_df9  = pd.DataFrame(emotionCounts9, index=df_all_data['texts9'].index)
emotion_df9 = emotion_df9.fillna(0)
emotion_df = emotion_df.add(emotion_df9, fill_value=0)
emotion_df10  = pd.DataFrame(emotionCounts10, index=df_all_data['texts10'].index)
emotion_df10 = emotion_df10.fillna(0)
emotion_df = emotion_df.add(emotion_df10, fill_value=0)
emotion_df11  = pd.DataFrame(emotionCounts11, index=df_all_data['texts11'].index)
emotion_df11 = emotion_df11.fillna(0)
emotion_df = emotion_df.add(emotion_df11, fill_value=0)
emotion_df12  = pd.DataFrame(emotionCounts12, index=df_all_data['texts12'].index)
emotion_df12 = emotion_df12.fillna(0)
emotion_df = emotion_df.add(emotion_df12, fill_value=0)
emotion_df13  = pd.DataFrame(emotionCounts13, index=df_all_data['texts13'].index)
emotion_df13 = emotion_df13.fillna(0)
emotion_df = emotion_df.add(emotion_df13, fill_value=0)
emotion_df14  = pd.DataFrame(emotionCounts14, index=df_all_data['texts14'].index)
emotion_df14 = emotion_df14.fillna(0)
emotion_df = emotion_df.add(emotion_df14, fill_value=0)
emotion_df15  = pd.DataFrame(emotionCounts15, index=df_all_data['texts15'].index)
emotion_df15 = emotion_df15.fillna(0)
emotion_df = emotion_df.add(emotion_df15, fill_value=0)
emotion_df16  = pd.DataFrame(emotionCounts16, index=df_all_data['texts16'].index)
emotion_df16 = emotion_df16.fillna(0)
emotion_df = emotion_df.add(emotion_df16, fill_value=0)
emotion_df17  = pd.DataFrame(emotionCounts17, index=df_all_data['texts17'].index)
emotion_df17 = emotion_df17.fillna(0)
emotion_df = emotion_df.add(emotion_df17, fill_value=0)
emotion_df
# Out:
#             anger  anticipation  disgust    fear     joy  negative  positive  \
# id
# 614         654.0        1082.0    390.0   805.0   996.0    1299.0    2371.0
# 1038         59.0         102.0     46.0    82.0    85.0     139.0     204.0
# 1437        629.0        1277.0    534.0   659.0  1072.0    1271.0    1931.0
# 2615        109.0         267.0     72.0   147.0   214.0     247.0     497.0
# 3148        240.0         804.0    113.0   277.0   656.0     456.0    1544.0
# 5593        116.0         318.0     98.0   153.0   258.0     288.0     632.0
# 6301        189.0        1097.0    100.0   263.0  1033.0     526.0    2463.0
# 9375         81.0         187.0     60.0   120.0   187.0     207.0     366.0
# 10336      1146.0        1258.0    661.0  1180.0  1094.0    2015.0    2883.0
# 10698        24.0          45.0     28.0    31.0    32.0      65.0      67.0
# 10836        10.0          60.0      8.0    16.0    55.0      26.0     136.0
# ...

# %%
emotion_df['id'] = emotion_df.index

# %%
#df_all_timepass = df_all_data.reset_index().merge(emotion_df, how="left").set_index(df_all_data.index.names)
df_all_data = pd.merge(df_all_data, emotion_df, left_index=True, right_index=True)

# %%
df_all_data.to_csv('Final_data.csv', index = True)

# %%
df_all_data = pd.read_csv('Final_data.csv', index_col='id', sep=',')

# %%
df_all_data
# Out:
#             id_str_x      screen_name                            location  \
# id
# 614              614       dcharrison               b'Salt Lake City, UT'
# 1038            1038          martijn           b'Hoograven, Utrecht, NL'
# 1437            1437           ryansk                b'Northern Virginia'
# 2615            2615          seannui                       b'Denver, CO'
# 3148            3148         mahadewa                  b'London, Jakarta'
# 5593            5593         jburkunk                        b'Amsterdam'
# 6301            6301       msjacbowie                b'Geelong, Victoria'
# 9375            9375        santhoshj                  b'Jersey City, NJ'
# 10336          10336           ElisaC                     b'San Jose, CA'
# 10698          10698         karawapo                   b'Fukuoka, Japan'
# 10836          10836        rex_huang                 b'China, Singapore'
# 10997          10997     philcampbell  b'Bulgaria, Estonia, Portugal, UK'
# ...

# %%
Additional feature building for our data

# %%
#function to create new features

def FindDates(x,valid):
    formated_date = ''
    months = {'Jan':1,'Feb':2,'Mar':3,'Apr':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}    
    if x.startswith('"') and x.endswith('"'): x = x[1:-1]
    if x.startswith("'") and x.endswith("'"): x = x[1:-1]
    if x.startswith("'"): x = x[1:]
    date_split = x.split(' ')
    if len(date_split) == 2:
        _date = date_split[0].split('/')
        _date[2] = _date[2]
        formated_date = '/'.join(map(str,_date))
        time = date_split[1]
        #print formated_date , date_split, pd.to_datetime(formated_date, format='%m/%d/%Y', errors='coerce')
    
    elif len(date_split) == 6:
        m = months[date_split[1]]
        formated_date = '/'.join(map(str,[m,date_split[2],date_split[5]]))
        if formated_date[-1] == '"': formated_date = formated_date[:-1]
        #print formated_date, date_split, pd.to_datetime(formated_date, format='%m/%d/%Y', errors='coerce')    
    
    if valid:
        return pd.to_datetime(formated_date, format='%m/%d/%Y', errors='coerce')
    else:
        return pd.to_datetime(time,format='%H:%M').hour
    
def get_json(x):
    if not pd.isnull(x) and x.find('_json=') != -1:
        x = x[x.find('_json=')+6:x.find(', source_url=')]
        x = ast.literal_eval(x)
        return x
    else:
        return None

def status_created_date(x):
    if not pd.isnull(x):
        x = get_json(x)
        if x is not None:
            x = FindDates(x['created_at'],True)
            return x
    return pd.to_datetime('05/05/2017', format='%m/%d/%Y', errors='coerce')
    
def status_created_at(df):
    df['status_created_at'] = df.status.apply(status_created_date)
    return df

def in_reply_stats(x):
    x = get_json(x)
    if x is not None:
        if x['in_reply_to_screen_name'] is not None:
            return 1
    return 0

def in_reply_data(df):
    df['in_reply_data'] = df.status.apply(in_reply_stats)
    return df

def tweet_text_data(x):
    x = get_json(x)
    if x is not None:
        return x['text']
    return 'a'

def tweet_text(df):
    df['tweet_text'] = df.status.apply(tweet_text_data)
    return df

def followers_to_friends(df):
    df.followers_count = df.followers_count.apply(lambda x: int(x)+1)
    df.friends_count = df.friends_count.apply(lambda x: int(x)+1)
    df.loc[:,'followers_to_friends'] = (df.followers_count/df.friends_count)
    return df

def tweets_per_day(df):
    df.loc[:,'statuses_count']= df.statuses_count.apply(lambda x: int(x)+1)
    df.loc[:,'tweets_per_day'] = df.statuses_count/df.acc_age
    return df

def drop_features(df):
    return df.drop(['id_str_x','id_str_y','id.1','location','lang','status','created_at_tweets1','created_at_tweets2','created_at_tweets3','created_at_tweets4','status_created_at',
                    'modified_date','screen_name','description','url','created_at','texts1', 'texts2','texts3', 'texts4','texts5','texts6', 'texts7', 'texts8', 'texts9',
                    'texts10','texts11', 'texts12', 'texts13', 'texts14', 'texts15','texts16','texts17'], axis=1)

def replace_None(df):
    df.loc[:,'has_extended_profile'] = df['has_extended_profile'].fillna(df.has_extended_profile.median())
    df.loc[:,'verified'] = df['verified'].apply(lambda x: 1 if x else 0)
    df.loc[:,'default_profile'] = df['default_profile'].apply(lambda x: 1 if x else 0)
    df.loc[:,'default_profile_image'] = df['default_profile_image'].apply(lambda x: 1 if x else 0)
    df.loc[:,'has_extended_profile'] = df['has_extended_profile'].apply(lambda x: 1 if x else 0)
    return df

def tweets_data_format(df):    
    df.loc[:,'In_reply'] = df['In_reply'].fillna(0)
    df.loc[:,'retweet_count'] = df['retweet_count'].fillna(0)
    df.loc[:,'fav_count'] = df['fav_count'].fillna(0)
    df.loc[:,'total_usrmention'] = df['total_usrmention'].fillna(0)   
    return df

def avg_tweets_attributes_count(df):
    df['avg_In_reply'] = df['In_reply']/df['Tweet_Downloaded']
    df['avg_retweet_count'] = df['retweet_count']/df['Tweet_Downloaded']
    df['avg_fav_count'] = df['fav_count']/df['Tweet_Downloaded']
    df['avg_total_usrmention'] = df['total_usrmention']/df['Tweet_Downloaded']
    return df    

def format_date(df):
    df.loc[:,'modified_date'] = df.created_at.apply(lambda x: FindDates(x,True))
    df.loc[:,'modified_hour'] = df.created_at.apply(lambda x: FindDates(x,False))
    return df

def diversity(df):
    df.loc[:,'description'].fillna("")    
    df.loc[:,'screen_name_length'] = df.screen_name.apply(lambda text: len(str(text)))
    df.loc[:,'description_length'] = df.description.apply(lambda text: len(str(text)))
    grouped = df['screen_name']
    df['diversity'] = grouped.apply(word_diversity)
    df.loc[:,"name_length"] = df.name.apply(lambda x: len(''.join(str(x))))
    df.loc[:,"name_words"] = df.name.apply(lambda x: len(str(x).strip().split()))    
    
    df.loc[:,'null_url'] = df.url.apply(lambda x: 1 if (str(x).find('http'))!=-1 else 0)
    df.loc[:,"screenname_bot"] = df.screen_name.apply(lambda x: 1 if ('bot' in str(x).lower()) else 0)
    df.loc[:,"name_bot"] = df.name.apply(lambda x: 1 if ('bot' in str(x).lower()) else 0)
    df.loc[:,"description_bot"] = df.description.apply(lambda x: 1 if ('bot' in str(x).lower()) else 0)
    df.loc[:,"nameratio"] = df.name.apply(lambda x: nameR(x))
    return df

def account_age(df):
    df['acc_age'] = (df['status_created_at'] - df['modified_date'])
    df['acc_age'] = df.acc_age.apply(lambda  x:int(x.days))
    for index,row in df.iterrows():
        if row['acc_age'] < 0:
            value = abs(int((pd.to_datetime('05/05/2017', format='%m/%d/%Y', errors='coerce') - pd.to_datetime(row['modified_date'])).days))
            df.set_value(index,'acc_age',value)
    df['acc_age'] += 1
    return df;

def avg_emotion_count(df):
    df['avg_anger'] = df['anger']/df['Tweet_Downloaded']
    df['avg_anticipation'] = df['anticipation']/df['Tweet_Downloaded']
    df['avg_disgust'] = df['disgust']/df['Tweet_Downloaded']
    df['avg_fear'] = df['fear']/df['Tweet_Downloaded']
    df['avg_joy'] = df['joy']/df['Tweet_Downloaded']
    df['avg_negative'] = df['negative']/df['Tweet_Downloaded']
    df['avg_positive'] = df['positive']/df['Tweet_Downloaded']
    df['avg_sadness'] = df['sadness']/df['Tweet_Downloaded']
    df['avg_surprise'] = df['surprise']/df['Tweet_Downloaded']
    df['avg_trust'] = df['trust']/df['Tweet_Downloaded']
    df['avg_negative_emoticon'] = df['negative_emoticon']/df['Tweet_Downloaded']
    df['avg_positive_emoticon'] = df['positive_emoticon']/df['Tweet_Downloaded']
    return df;
    
def word_diversity(text):
  if (len(text) == 0):
    diversity = 0
  else:
    diversity = float(len(set(text))) / len(text)
  return diversity

    
def get_Noun(x):
    word = str(x).strip()
    count = 0
    tagged_sent = pos_tag(word.split())
    for w in tagged_sent:
        if w[1] == 'NNP':
            count+=1
    return count

def nameR(x):
    wordlen = len(str(x).strip().split())
    letters = len(''.join(str(x).strip().split()))
    return letters/wordlen

# %%
def build_features(df):  
    df = status_created_at(df)
    df = format_date(df)
    df = account_age(df)
    df = tweets_data_format(df)
    df = tweets_per_day(df)
    df = in_reply_data(df)    
    df = followers_to_friends(df)
    df = replace_None(df)  
    df = diversity(df)
    df = avg_tweets_attributes_count(df)
    df = avg_emotion_count(df)
    df = drop_features(df)
    return df


all_data = build_features(df_all_data)

# %%
all_data.head()
# Out:
#       followers_count  friends_count  listedcount  favourites_count  verified  \
# id
# 614              1718           2202           52              4634         0
# 1038             1427           1015           78              4272         0
# 1437              308            205            8               359         0
# 2615              795            681           33                85         0
# 3148             8015           3854          331              1635         0
#
#       statuses_count  default_profile  default_profile_image  \
# id
# 614            14160                0                      0
# 1038           33029                0                      0
# 1437            3141                0                      0
# 2615             776                0                      0
# 3148           30154                0                      0
#
#       has_extended_profile                   name          ...            \
# ...

# %%
all_data.to_csv('Processed_final.csv', index = True)

# %%
all_data = pd.read_csv('Processed_final.csv', index_col='id', sep=',')
all_data.head()
# Out:
#       followers_count  friends_count  listedcount  favourites_count  verified  \
# id
# 614              1718           2202           52              4634         0
# 1038             1427           1015           78              4272         0
# 1437              308            205            8               359         0
# 2615              795            681           33                85         0
# 3148             8015           3854          331              1635         0
#
#       statuses_count  default_profile  default_profile_image  \
# id
# 614            14160                0                      0
# 1038           33029                0                      0
# 1437            3141                0                      0
# 2615             776                0                      0
# 3148           30154                0                      0
#
#       has_extended_profile                   name          ...            \
# ...

# %%
plt.title('Number of bot vs Number of people', y=1, size=20)
sns.countplot('bot', data=all_data)

# %%
df_train.to_csv('Train.csv', index = True)
df_test.to_csv('Test.csv', index = True)

# %%
X_combine = df_train
X_all = X_combine.drop(['bot','name'], axis=1)
Y_all = X_combine['bot']

# %%
X_combine = df_test
X_test = X_combine.drop(['bot','name'], axis=1)
Y_test = X_combine['bot']

# %%
from sklearn.ensemble import ExtraTreesClassifier
model2 = ExtraTreesClassifier()
model2.fit(X_all, Y_all)

#Add features and their importances to a dictionary
feature_imp_dict = dict(zip(X_all.columns.values, model2.feature_importances_))

for x in sorted(zip(model2.feature_importances_,list(X_all)))[::-1]:
    print (x)
# Out:
# (0.09355411980145875, 'id.1.1')
# (0.088477370918099, 'friends_count')
# (0.07663066272592609, 'followers_count')
# (0.06079424609765745, 'followers_to_friends')
# (0.05602515320866538, 'acc_age')
# (0.029970455561368882, 'In_reply')
# (0.025792084248415496, 'statuses_count')
# (0.024582775116115237, 'has_extended_profile')
# (0.024165649026347942, 'tweets_per_day')
# (0.022500932498736338, 'null_url')
# (0.0218676099009043, 'listedcount')
# (0.0213592367516559, 'avg_total_usrmention')
# (0.020393336170749583, 'avg_trust')
# (0.01930281694884594, 'total_usrmention')
# (0.018740351081088107, 'avg_In_reply')
# (0.017146886888814303, 'avg_positive')
# (0.015246990194008728, 'avg_retweet_count')
# (0.015150294862864292, 'description_length')
# (0.013365132972813202, 'positive')
# (0.013140846624599186, 'default_profile')
# (0.012775287258383053, 'favourites_count')
# (0.01194179681422396, 'positive_emoticon')
# (0.011556349410926484, 'trust')
# ...

# %%
#define a function to print ROC curves. 
#It should take in only arrays/lists of predictions and outcomes
from sklearn.metrics import roc_curve, auc

def plotSingleVariableROC(preds, truth, label_string):
    '''
    preds is an nx1 array of predictions
    truth is an nx1 array of truth labels
    label_string is text to go into the plotting label
    '''
    #Student input code here
    #1. call the roc_curve function to get the ROC X and Y values
    fpr, tpr, thresholds = roc_curve(truth, preds)
    #2. Input fpr and tpr into the auc function to get the AUC
    roc_auc = auc(fpr, tpr)
    
    #we are doing this as a special case because we are sending unfitted predictions
    #into the function
    if roc_auc < 0.5:
        fpr, tpr, thresholds = roc_curve(truth, -1 * preds)
        roc_auc = auc(fpr, tpr)

    #chooses a random color for plotting
    c = (np.random.rand(), np.random.rand(), np.random.rand())

    #create a plot and set some options
    plt.plot(fpr, tpr, color = c, label = label_string + ' (AUC = %0.3f)' % roc_auc)
    

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC')
    plt.legend(loc="lower right")
    
    return roc_auc

# %%
fig = plt.figure(figsize = (12, 6))
ax = plt.subplot(111)

#Plot the univariate AUC on the training data. Store the AUC

#Student put code here
feature_auc_dict = {}
for col in X_all.columns:
    feature_auc_dict[col] = plotSingleVariableROC(X_all[col], Y_all, col)


# Put a legend below current axis
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.0 , box.width, box.height * 1])
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.15), fancybox = True, 
              shadow = True, ncol = 4, prop = {'size':10})
